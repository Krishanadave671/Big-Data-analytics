# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.4.0.tar.gz (310.8 MB)
#      -------------------------------------- 310.8/310.8 MB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      -------------------------------------- 200.5/200.5 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: py4j, pyspark
#   Running setup.py install for pyspark: started
#   Running setup.py install for pyspark: finished with status 'error'
#   DEPRECATION: pyspark is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for pyspark did not run successfully.
#   │ exit code: 1
#   ╰─> [2020 lines of output]
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\dist.py:771: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#         warnings.warn(
#       running install
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build\lib
#       creating build\lib\pyspark
#       copying pyspark\accumulators.py -> build\lib\pyspark
#       copying pyspark\broadcast.py -> build\lib\pyspark
#       copying pyspark\conf.py -> build\lib\pyspark
#       copying pyspark\context.py -> build\lib\pyspark
#       copying pyspark\daemon.py -> build\lib\pyspark
#       copying pyspark\files.py -> build\lib\pyspark
#       copying pyspark\find_spark_home.py -> build\lib\pyspark
#       copying pyspark\install.py -> build\lib\pyspark
#       copying pyspark\instrumentation_utils.py -> build\lib\pyspark
#       copying pyspark\java_gateway.py -> build\lib\pyspark
#       copying pyspark\join.py -> build\lib\pyspark
#       copying pyspark\profiler.py -> build\lib\pyspark
#       copying pyspark\rdd.py -> build\lib\pyspark
#       copying pyspark\rddsampler.py -> build\lib\pyspark
#       copying pyspark\resultiterable.py -> build\lib\pyspark
#       copying pyspark\serializers.py -> build\lib\pyspark
#       copying pyspark\shell.py -> build\lib\pyspark
#       copying pyspark\shuffle.py -> build\lib\pyspark
#       copying pyspark\statcounter.py -> build\lib\pyspark
#       copying pyspark\status.py -> build\lib\pyspark
#       copying pyspark\storagelevel.py -> build\lib\pyspark
#       copying pyspark\taskcontext.py -> build\lib\pyspark
#       copying pyspark\traceback_utils.py -> build\lib\pyspark
#       copying pyspark\util.py -> build\lib\pyspark
#       copying pyspark\version.py -> build\lib\pyspark
#       copying pyspark\worker.py -> build\lib\pyspark
#       copying pyspark\_globals.py -> build\lib\pyspark
#       copying pyspark\__init__.py -> build\lib\pyspark
#       creating build\lib\pyspark\cloudpickle
#       copying pyspark\cloudpickle\cloudpickle.py -> build\lib\pyspark\cloudpickle
#       copying pyspark\cloudpickle\cloudpickle_fast.py -> build\lib\pyspark\cloudpickle
#       copying pyspark\cloudpickle\compat.py -> build\lib\pyspark\cloudpickle
#       copying pyspark\cloudpickle\__init__.py -> build\lib\pyspark\cloudpickle
#       creating build\lib\pyspark\mllib
#       copying pyspark\mllib\classification.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\clustering.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\common.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\evaluation.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\feature.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\fpm.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\random.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\recommendation.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\regression.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\tree.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\util.py -> build\lib\pyspark\mllib
#       copying pyspark\mllib\__init__.py -> build\lib\pyspark\mllib
#       creating build\lib\pyspark\mllib\linalg
#       copying pyspark\mllib\linalg\distributed.py -> build\lib\pyspark\mllib\linalg
#       copying pyspark\mllib\linalg\__init__.py -> build\lib\pyspark\mllib\linalg
#       creating build\lib\pyspark\mllib\stat
#       copying pyspark\mllib\stat\distribution.py -> build\lib\pyspark\mllib\stat
#       copying pyspark\mllib\stat\KernelDensity.py -> build\lib\pyspark\mllib\stat
#       copying pyspark\mllib\stat\test.py -> build\lib\pyspark\mllib\stat
#       copying pyspark\mllib\stat\_statistics.py -> build\lib\pyspark\mllib\stat
#       copying pyspark\mllib\stat\__init__.py -> build\lib\pyspark\mllib\stat
#       creating build\lib\pyspark\ml
#       copying pyspark\ml\base.py -> build\lib\pyspark\ml
#       copying pyspark\ml\classification.py -> build\lib\pyspark\ml
#       copying pyspark\ml\clustering.py -> build\lib\pyspark\ml
#       copying pyspark\ml\common.py -> build\lib\pyspark\ml
#       copying pyspark\ml\evaluation.py -> build\lib\pyspark\ml
#       copying pyspark\ml\feature.py -> build\lib\pyspark\ml
#       copying pyspark\ml\fpm.py -> build\lib\pyspark\ml
#       copying pyspark\ml\functions.py -> build\lib\pyspark\ml
#       copying pyspark\ml\image.py -> build\lib\pyspark\ml
#       copying pyspark\ml\model_cache.py -> build\lib\pyspark\ml
#       copying pyspark\ml\pipeline.py -> build\lib\pyspark\ml
#       copying pyspark\ml\recommendation.py -> build\lib\pyspark\ml
#       copying pyspark\ml\regression.py -> build\lib\pyspark\ml
#       copying pyspark\ml\stat.py -> build\lib\pyspark\ml
#       copying pyspark\ml\tree.py -> build\lib\pyspark\ml
#       copying pyspark\ml\tuning.py -> build\lib\pyspark\ml
#       copying pyspark\ml\util.py -> build\lib\pyspark\ml
#       copying pyspark\ml\wrapper.py -> build\lib\pyspark\ml
#       copying pyspark\ml\__init__.py -> build\lib\pyspark\ml
#       creating build\lib\pyspark\ml\linalg
#       copying pyspark\ml\linalg\__init__.py -> build\lib\pyspark\ml\linalg
#       creating build\lib\pyspark\ml\param
#       copying pyspark\ml\param\shared.py -> build\lib\pyspark\ml\param
#       copying pyspark\ml\param\_shared_params_code_gen.py -> build\lib\pyspark\ml\param
#       copying pyspark\ml\param\__init__.py -> build\lib\pyspark\ml\param
#       creating build\lib\pyspark\ml\torch
#       copying pyspark\ml\torch\distributor.py -> build\lib\pyspark\ml\torch
#       copying pyspark\ml\torch\log_communication.py -> build\lib\pyspark\ml\torch
#       copying pyspark\ml\torch\torch_run_process_wrapper.py -> build\lib\pyspark\ml\torch
#       copying pyspark\ml\torch\__init__.py -> build\lib\pyspark\ml\torch
#       creating build\lib\pyspark\sql
#       copying pyspark\sql\catalog.py -> build\lib\pyspark\sql
#       copying pyspark\sql\column.py -> build\lib\pyspark\sql
#       copying pyspark\sql\conf.py -> build\lib\pyspark\sql
#       copying pyspark\sql\context.py -> build\lib\pyspark\sql
#       copying pyspark\sql\dataframe.py -> build\lib\pyspark\sql
#       copying pyspark\sql\functions.py -> build\lib\pyspark\sql
#       copying pyspark\sql\group.py -> build\lib\pyspark\sql
#       copying pyspark\sql\observation.py -> build\lib\pyspark\sql
#       copying pyspark\sql\readwriter.py -> build\lib\pyspark\sql
#       copying pyspark\sql\session.py -> build\lib\pyspark\sql
#       copying pyspark\sql\sql_formatter.py -> build\lib\pyspark\sql
#       copying pyspark\sql\types.py -> build\lib\pyspark\sql
#       copying pyspark\sql\udf.py -> build\lib\pyspark\sql
#       copying pyspark\sql\utils.py -> build\lib\pyspark\sql
#       copying pyspark\sql\window.py -> build\lib\pyspark\sql
#       copying pyspark\sql\__init__.py -> build\lib\pyspark\sql
#       creating build\lib\pyspark\sql\avro
#       copying pyspark\sql\avro\functions.py -> build\lib\pyspark\sql\avro
#       copying pyspark\sql\avro\__init__.py -> build\lib\pyspark\sql\avro
#       creating build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\catalog.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\client.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\column.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\conf.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\conversion.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\dataframe.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\expressions.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\functions.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\group.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\plan.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\readwriter.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\session.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\types.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\udf.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\utils.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\window.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\_typing.py -> build\lib\pyspark\sql\connect
#       copying pyspark\sql\connect\__init__.py -> build\lib\pyspark\sql\connect
#       creating build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\base_pb2.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\base_pb2_grpc.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\catalog_pb2.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\commands_pb2.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\common_pb2.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\example_plugins_pb2.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\expressions_pb2.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\relations_pb2.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\types_pb2.py -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\__init__.py -> build\lib\pyspark\sql\connect\proto
#       creating build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\conversion.py -> build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\functions.py -> build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\group_ops.py -> build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\map_ops.py -> build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\serializers.py -> build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\typehints.py -> build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\types.py -> build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\utils.py -> build\lib\pyspark\sql\pandas
#       copying pyspark\sql\pandas\__init__.py -> build\lib\pyspark\sql\pandas
#       creating build\lib\pyspark\sql\protobuf
#       copying pyspark\sql\protobuf\functions.py -> build\lib\pyspark\sql\protobuf
#       copying pyspark\sql\protobuf\__init__.py -> build\lib\pyspark\sql\protobuf
#       creating build\lib\pyspark\sql\streaming
#       copying pyspark\sql\streaming\listener.py -> build\lib\pyspark\sql\streaming
#       copying pyspark\sql\streaming\query.py -> build\lib\pyspark\sql\streaming
#       copying pyspark\sql\streaming\readwriter.py -> build\lib\pyspark\sql\streaming
#       copying pyspark\sql\streaming\state.py -> build\lib\pyspark\sql\streaming
#       copying pyspark\sql\streaming\__init__.py -> build\lib\pyspark\sql\streaming
#       creating build\lib\pyspark\streaming
#       copying pyspark\streaming\context.py -> build\lib\pyspark\streaming
#       copying pyspark\streaming\dstream.py -> build\lib\pyspark\streaming
#       copying pyspark\streaming\kinesis.py -> build\lib\pyspark\streaming
#       copying pyspark\streaming\listener.py -> build\lib\pyspark\streaming
#       copying pyspark\streaming\util.py -> build\lib\pyspark\streaming
#       copying pyspark\streaming\__init__.py -> build\lib\pyspark\streaming
#       creating build\lib\pyspark\pandas
#       copying pyspark\pandas\accessors.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\base.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\categorical.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\config.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\correlation.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\datetimes.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\exceptions.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\extensions.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\frame.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\generic.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\groupby.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\indexing.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\internal.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\mlflow.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\namespace.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\numpy_compat.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\resample.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\series.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\sql_formatter.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\sql_processor.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\strings.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\supported_api_gen.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\utils.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\window.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\_typing.py -> build\lib\pyspark\pandas
#       copying pyspark\pandas\__init__.py -> build\lib\pyspark\pandas
#       creating build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\base.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\binary_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\boolean_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\categorical_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\complex_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\datetime_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\date_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\null_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\num_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\string_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\timedelta_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\udt_ops.py -> build\lib\pyspark\pandas\data_type_ops
#       copying pyspark\pandas\data_type_ops\__init__.py -> build\lib\pyspark\pandas\data_type_ops
#       creating build\lib\pyspark\pandas\indexes
#       copying pyspark\pandas\indexes\base.py -> build\lib\pyspark\pandas\indexes
#       copying pyspark\pandas\indexes\category.py -> build\lib\pyspark\pandas\indexes
#       copying pyspark\pandas\indexes\datetimes.py -> build\lib\pyspark\pandas\indexes
#       copying pyspark\pandas\indexes\multi.py -> build\lib\pyspark\pandas\indexes
#       copying pyspark\pandas\indexes\numeric.py -> build\lib\pyspark\pandas\indexes
#       copying pyspark\pandas\indexes\timedelta.py -> build\lib\pyspark\pandas\indexes
#       copying pyspark\pandas\indexes\__init__.py -> build\lib\pyspark\pandas\indexes
#       creating build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\common.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\frame.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\general_functions.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\groupby.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\indexes.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\resample.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\scalars.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\series.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\window.py -> build\lib\pyspark\pandas\missing
#       copying pyspark\pandas\missing\__init__.py -> build\lib\pyspark\pandas\missing
#       creating build\lib\pyspark\pandas\plot
#       copying pyspark\pandas\plot\core.py -> build\lib\pyspark\pandas\plot
#       copying pyspark\pandas\plot\matplotlib.py -> build\lib\pyspark\pandas\plot
#       copying pyspark\pandas\plot\plotly.py -> build\lib\pyspark\pandas\plot
#       copying pyspark\pandas\plot\__init__.py -> build\lib\pyspark\pandas\plot
#       creating build\lib\pyspark\pandas\spark
#       copying pyspark\pandas\spark\accessors.py -> build\lib\pyspark\pandas\spark
#       copying pyspark\pandas\spark\functions.py -> build\lib\pyspark\pandas\spark
#       copying pyspark\pandas\spark\utils.py -> build\lib\pyspark\pandas\spark
#       copying pyspark\pandas\spark\__init__.py -> build\lib\pyspark\pandas\spark
#       creating build\lib\pyspark\pandas\typedef
#       copying pyspark\pandas\typedef\typehints.py -> build\lib\pyspark\pandas\typedef
#       copying pyspark\pandas\typedef\__init__.py -> build\lib\pyspark\pandas\typedef
#       creating build\lib\pyspark\pandas\usage_logging
#       copying pyspark\pandas\usage_logging\usage_logger.py -> build\lib\pyspark\pandas\usage_logging
#       copying pyspark\pandas\usage_logging\__init__.py -> build\lib\pyspark\pandas\usage_logging
#       creating build\lib\pyspark\python
#       creating build\lib\pyspark\python\pyspark
#       copying pyspark\python\pyspark\shell.py -> build\lib\pyspark\python\pyspark
#       creating build\lib\pyspark\resource
#       copying pyspark\resource\information.py -> build\lib\pyspark\resource
#       copying pyspark\resource\profile.py -> build\lib\pyspark\resource
#       copying pyspark\resource\requests.py -> build\lib\pyspark\resource
#       copying pyspark\resource\__init__.py -> build\lib\pyspark\resource
#       creating build\lib\pyspark\errors
#       copying pyspark\errors\error_classes.py -> build\lib\pyspark\errors
#       copying pyspark\errors\utils.py -> build\lib\pyspark\errors
#       copying pyspark\errors\__init__.py -> build\lib\pyspark\errors
#       creating build\lib\pyspark\errors\exceptions
#       copying pyspark\errors\exceptions\base.py -> build\lib\pyspark\errors\exceptions
#       copying pyspark\errors\exceptions\captured.py -> build\lib\pyspark\errors\exceptions
#       copying pyspark\errors\exceptions\connect.py -> build\lib\pyspark\errors\exceptions
#       copying pyspark\errors\exceptions\__init__.py -> build\lib\pyspark\errors\exceptions
#       creating build\lib\pyspark\examples
#       creating build\lib\pyspark\examples\src
#       creating build\lib\pyspark\examples\src\main
#       creating build\lib\pyspark\examples\src\main\python
#       copying deps\examples\als.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\avro_inputformat.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\kmeans.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\logistic_regression.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\pagerank.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\parquet_inputformat.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\pi.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\sort.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\status_api_demo.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\transitive_closure.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\wordcount.py -> build\lib\pyspark\examples\src\main\python
#       copying deps\examples\__init__.py -> build\lib\pyspark\examples\src\main\python
#       running egg_info
#       writing pyspark.egg-info\PKG-INFO
#       writing dependency_links to pyspark.egg-info\dependency_links.txt
#       writing requirements to pyspark.egg-info\requires.txt
#       writing top-level names to pyspark.egg-info\top_level.txt
#       reading manifest file 'pyspark.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*.py[cod]' found anywhere in distribution
#       warning: no previously-included files matching '__pycache__' found anywhere in distribution
#       warning: no previously-included files matching '.DS_Store' found anywhere in distribution
#       writing manifest file 'pyspark.egg-info\SOURCES.txt'
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.data.graphx' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.data.graphx' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.data.graphx' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.data.graphx' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.data.mllib' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.data.mllib' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.data.mllib' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.data.mllib' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.data.mllib.als' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.data.mllib.als' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.data.mllib.als' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.data.mllib.als' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.data.mllib.images' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.data.mllib.images' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.data.mllib.images' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.data.mllib.images' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.data.mllib.images.origin' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.data.mllib.images.origin' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.data.mllib.images.origin' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.data.mllib.images.origin' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.data.mllib.images.origin.kittens' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.data.mllib.images.origin.kittens' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.data.mllib.images.origin.kittens' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.data.mllib.images.origin.kittens' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.data.streaming' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.data.streaming' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.data.streaming' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.data.streaming' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.examples.src.main.python.ml' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.examples.src.main.python.ml' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.examples.src.main.python.ml' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.examples.src.main.python.ml' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.examples.src.main.python.mllib' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.examples.src.main.python.mllib' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.examples.src.main.python.mllib' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.examples.src.main.python.mllib' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.examples.src.main.python.sql' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.examples.src.main.python.sql' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.examples.src.main.python.sql' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.examples.src.main.python.sql' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.examples.src.main.python.sql.streaming' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.examples.src.main.python.sql.streaming' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.examples.src.main.python.sql.streaming' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.examples.src.main.python.sql.streaming' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.examples.src.main.python.streaming' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.examples.src.main.python.streaming' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.examples.src.main.python.streaming' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.examples.src.main.python.streaming' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.sql.pandas._typing' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.sql.pandas._typing' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.sql.pandas._typing' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.sql.pandas._typing' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pyspark.sql.pandas._typing.protocols' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pyspark.sql.pandas._typing.protocols' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pyspark.sql.pandas._typing.protocols' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pyspark.sql.pandas._typing.protocols' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       copying pyspark\_typing.pyi -> build\lib\pyspark
#       copying pyspark\py.typed -> build\lib\pyspark
#       copying pyspark\mllib\_typing.pyi -> build\lib\pyspark\mllib
#       copying pyspark\ml\_typing.pyi -> build\lib\pyspark\ml
#       copying pyspark\sql\_typing.pyi -> build\lib\pyspark\sql
#       copying pyspark\sql\connect\proto\base_pb2.pyi -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\catalog_pb2.pyi -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\commands_pb2.pyi -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\common_pb2.pyi -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\example_plugins_pb2.pyi -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\expressions_pb2.pyi -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\relations_pb2.pyi -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\connect\proto\types_pb2.pyi -> build\lib\pyspark\sql\connect\proto
#       copying pyspark\sql\pandas\functions.pyi -> build\lib\pyspark\sql\pandas
#       creating build\lib\pyspark\sql\pandas\_typing
#       copying pyspark\sql\pandas\_typing\__init__.pyi -> build\lib\pyspark\sql\pandas\_typing
#       creating build\lib\pyspark\sql\pandas\_typing\protocols
#       copying pyspark\sql\pandas\_typing\protocols\__init__.pyi -> build\lib\pyspark\sql\pandas\_typing\protocols
#       copying pyspark\sql\pandas\_typing\protocols\frame.pyi -> build\lib\pyspark\sql\pandas\_typing\protocols
#       copying pyspark\sql\pandas\_typing\protocols\series.pyi -> build\lib\pyspark\sql\pandas\_typing\protocols
#       creating build\lib\pyspark\bin
#       copying deps\bin\beeline -> build\lib\pyspark\bin
#       copying deps\bin\beeline.cmd -> build\lib\pyspark\bin
#       copying deps\bin\docker-image-tool.sh -> build\lib\pyspark\bin
#       copying deps\bin\find-spark-home -> build\lib\pyspark\bin
#       copying deps\bin\find-spark-home.cmd -> build\lib\pyspark\bin
#       copying deps\bin\load-spark-env.cmd -> build\lib\pyspark\bin
#       copying deps\bin\load-spark-env.sh -> build\lib\pyspark\bin
#       copying deps\bin\pyspark -> build\lib\pyspark\bin
#       copying deps\bin\pyspark.cmd -> build\lib\pyspark\bin
#       copying deps\bin\pyspark2.cmd -> build\lib\pyspark\bin
#       copying deps\bin\run-example -> build\lib\pyspark\bin
#       copying deps\bin\run-example.cmd -> build\lib\pyspark\bin
#       copying deps\bin\spark-class -> build\lib\pyspark\bin
#       copying deps\bin\spark-class.cmd -> build\lib\pyspark\bin
#       copying deps\bin\spark-class2.cmd -> build\lib\pyspark\bin
#       copying deps\bin\spark-connect-shell -> build\lib\pyspark\bin
#       copying deps\bin\spark-shell -> build\lib\pyspark\bin
#       copying deps\bin\spark-shell.cmd -> build\lib\pyspark\bin
#       copying deps\bin\spark-shell2.cmd -> build\lib\pyspark\bin
#       copying deps\bin\spark-sql -> build\lib\pyspark\bin
#       copying deps\bin\spark-sql.cmd -> build\lib\pyspark\bin
#       copying deps\bin\spark-sql2.cmd -> build\lib\pyspark\bin
#       copying deps\bin\spark-submit -> build\lib\pyspark\bin
#       copying deps\bin\spark-submit.cmd -> build\lib\pyspark\bin
#       copying deps\bin\spark-submit2.cmd -> build\lib\pyspark\bin
#       copying deps\bin\sparkR -> build\lib\pyspark\bin
#       copying deps\bin\sparkR.cmd -> build\lib\pyspark\bin
#       copying deps\bin\sparkR2.cmd -> build\lib\pyspark\bin
#       creating build\lib\pyspark\sbin
#       copying deps\sbin\spark-config.sh -> build\lib\pyspark\sbin
#       copying deps\sbin\spark-daemon.sh -> build\lib\pyspark\sbin
#       copying deps\sbin\start-history-server.sh -> build\lib\pyspark\sbin
#       copying deps\sbin\stop-history-server.sh -> build\lib\pyspark\sbin
#       creating build\lib\pyspark\jars
#       copying deps\jars\HikariCP-2.5.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\JLargeArrays-1.5.jar -> build\lib\pyspark\jars
#       copying deps\jars\JTransforms-3.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\RoaringBitmap-0.9.38.jar -> build\lib\pyspark\jars
#       copying deps\jars\ST4-4.0.4.jar -> build\lib\pyspark\jars
#       copying deps\jars\activation-1.1.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\aircompressor-0.21.jar -> build\lib\pyspark\jars
#       copying deps\jars\algebra_2.12-2.0.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\annotations-17.0.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\antlr-runtime-3.5.2.jar -> build\lib\pyspark\jars
#       copying deps\jars\antlr4-runtime-4.9.3.jar -> build\lib\pyspark\jars
#       copying deps\jars\aopalliance-repackaged-2.6.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\arpack-3.0.3.jar -> build\lib\pyspark\jars
#       copying deps\jars\arpack_combined_all-0.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\arrow-format-11.0.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\arrow-memory-core-11.0.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\arrow-memory-netty-11.0.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\arrow-vector-11.0.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\audience-annotations-0.5.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\avro-1.11.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\avro-ipc-1.11.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\avro-mapred-1.11.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\blas-3.0.3.jar -> build\lib\pyspark\jars
#       copying deps\jars\bonecp-0.8.0.RELEASE.jar -> build\lib\pyspark\jars
#       copying deps\jars\breeze-macros_2.12-2.1.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\breeze_2.12-2.1.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\cats-kernel_2.12-2.1.1.jar -> build\lib\pyspark\jars
#       copying deps\jars\chill-java-0.10.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\chill_2.12-0.10.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-cli-1.5.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-codec-1.15.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-collections-3.2.2.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-collections4-4.4.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-compiler-3.1.9.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-compress-1.22.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-crypto-1.1.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-dbcp-1.4.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-io-2.11.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-lang-2.6.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-lang3-3.12.0.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-logging-1.1.3.jar -> build\lib\pyspark\jars
#       copying deps\jars\commons-math3-3.6.1.jar -> build\lib\pyspark\jars
# ...
#       copying build\lib\pyspark\__init__.py -> C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\accumulators.py to accumulators.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\broadcast.py to broadcast.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\cloudpickle\cloudpickle.py to cloudpickle.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\cloudpickle\cloudpickle_fast.py to cloudpickle_fast.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\cloudpickle\compat.py to compat.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\cloudpickle\__init__.py to __init__.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\conf.py to conf.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\context.py to context.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\daemon.py to daemon.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\errors\error_classes.py to error_classes.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\errors\exceptions\base.py to base.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\errors\exceptions\captured.py to captured.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\errors\exceptions\connect.py to connect.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\errors\exceptions\__init__.py to __init__.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\errors\utils.py to utils.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\errors\__init__.py to __init__.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\als.py to als.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\avro_inputformat.py to avro_inputformat.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\kmeans.py to kmeans.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\logistic_regression.py to logistic_regression.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\aft_survival_regression.py to aft_survival_regression.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\als_example.py to als_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\binarizer_example.py to binarizer_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\bisecting_k_means_example.py to bisecting_k_means_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\bucketed_random_projection_lsh_example.py to bucketed_random_projection_lsh_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\bucketizer_example.py to bucketizer_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\chisq_selector_example.py to chisq_selector_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\chi_square_test_example.py to chi_square_test_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\correlation_example.py to correlation_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\count_vectorizer_example.py to count_vectorizer_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\cross_validator.py to cross_validator.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\dataframe_example.py to dataframe_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\dct_example.py to dct_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\decision_tree_classification_example.py to decision_tree_classification_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\decision_tree_regression_example.py to decision_tree_regression_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\elementwise_product_example.py to elementwise_product_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\estimator_transformer_param_example.py to estimator_transformer_param_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\feature_hasher_example.py to feature_hasher_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\fm_classifier_example.py to fm_classifier_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\fm_regressor_example.py to fm_regressor_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\fpgrowth_example.py to fpgrowth_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\gaussian_mixture_example.py to gaussian_mixture_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\generalized_linear_regression_example.py to generalized_linear_regression_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\gradient_boosted_tree_classifier_example.py to gradient_boosted_tree_classifier_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\gradient_boosted_tree_regressor_example.py to gradient_boosted_tree_regressor_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\imputer_example.py to imputer_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\index_to_string_example.py to index_to_string_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\interaction_example.py to interaction_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\isotonic_regression_example.py to isotonic_regression_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\kmeans_example.py to kmeans_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\lda_example.py to lda_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\linearsvc.py to linearsvc.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\linear_regression_with_elastic_net.py to linear_regression_with_elastic_net.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\logistic_regression_summary_example.py to logistic_regression_summary_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\logistic_regression_with_elastic_net.py to logistic_regression_with_elastic_net.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\max_abs_scaler_example.py to max_abs_scaler_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\min_hash_lsh_example.py to min_hash_lsh_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\min_max_scaler_example.py to min_max_scaler_example.cpython-310.pyc
#       byte-compiling C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyspark\examples\src\main\python\ml\multiclass_logistic_regression_with_elastic_net.py to multiclass_logistic_regression_with_elastic_net.cpython-310.pyc
#       error: [Errno 2] No such file or directory: 'C:\\Users\\krish\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\pyspark\\examples\\src\\main\\python\\ml\\__pycache__\\multiclass_logistic_regression_with_elastic_net.cpython-310.pyc.2259373567008'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pyspark
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\krish\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
pd.read_csv('test1.csv')
# Out:
#        name  age
# 0  krishana   21
# 1   Mohini    20
# 2    soham    14

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('first').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.40:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>first</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv('test1.csv')

# %%
df_pyspark.show()
# Out:
# +--------+---+
# |     _c0|_c1|
# +--------+---+
# |    name|age|
# |krishana| 21|
# | Mohini | 20|
# |  soham | 14|
# +--------+---+

# %%
df_pyspark = spark.read.option('header', 'true').csv('test1.csv')

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(name='krishana', age=' 21'),
#  Row(name='Mohini ', age=' 20'),
#  Row(name='soham ', age=' 14')]

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
